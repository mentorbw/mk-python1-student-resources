# %% [markdown]
# ## MakerKids Python - Level 1 - Week 1 - Intro

# %% [markdown]
# ### 1. Our first program:
# Our goal is to write a python code that displays the words: Hello world
# You can type your code into the cell below

# %% [markdown]
# ### 2. Comments:
# Comments allow us to leave messages in our code that wont be run by python.
# This is useful for reminding ourselves of what certain lines of code do,
# and for stopping certain lines of code from running without deleting them.

# %% [markdown]
# ### 3. Data types:
# There are 4 basic data types in python that we'll explore now, try printing them below as your instructor shows them.

# %%
# 1. String
# Add a string value to this print statement:
print()

# 2. Integer
# Add a integer value to this print statement:
print()

# 3. Float
# Add a float value to this print statement:
print()

# 4. Boolean
# Add a boolean value to this print statement:
print()

# %% [markdown]
# ### 4. Variables
# When we want to keep track of values we store them in **variables**.
# Variables are like labels that we use to store and refer to data.

# %%
# Try creating some variables here along with your instructor:

# %% [markdown]
# ### Practice Time!
# Try completing the following coding task(s) in the cell(s) below.
# 1) Display the words: this is coding
# 2) Create a *variable* called `name` with your name as the value. Display the `name` variable.
# 3) Create a *variable* called `chairs` whose value is the number of chairs in the room. Display the `chairs` variable.

# %%
# Challenge 1:

# %%
# Challenge 2:

# %%
# Challenge 3:

# %% [markdown]
# ### 5. Input
# The input function allows us receive information from a user. We can use this to create interactive programs.

# %%
# Try creating an input statement with your instructor.

# %% [markdown]
# ### 6. Formatted Strings
# Using a formatted string we can easily insert variables and values into our strings to display them. We can also create a multi line string the same way we create a multi line comment.

# %%
# Create a formatted string with your instructor.

# %% [markdown]
# ### Practice Time!
# Try completing the following coding task(s) in the cell(s) below.
# 1) Ask a user to enter their name and then greet them by name using a formatted string.

# %%
# Challenge 1:

# %% [markdown]
# ### 7. Math
# The moment you've been waiting for! Lets try out some arithmetic operators.

# %%
# Addition:
print()

# Subtraction:
print()

# Multiplication:
print()

# Division:
print()

# Integer division:
print()

# Exponents (powers):
print()

# %% [markdown]
# ### 8. Type conversion:
# Sometimes we need to change values from one type to another.

# %%
# Convert to a string:

# Convert to an integer:

# Convert to a decimal number:

# Convert to a boolean:

# %% [markdown]
# ### Project Time: Temperature Calculator
#
# In a new python file, create a program that allows users to convert a temerature from celsius to fahrenheit.
# The program should do the following:
# 1. Display a welcome message.
#
# 2. Ask the user for a temperature in degrees celcius.
#
# 3. Convert the temperature to fahrenheit *(__Hint:__  temp_celcius x 1.8 + 32  = temp_fahrenheit)*.
#
# 4. Tell the user what their converted temperature is.
