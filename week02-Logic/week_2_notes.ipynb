# %% [markdown]
# ## MakerKids Python - Level 1 - Week 2 - Logic

# %% [markdown]
# ### 1. If statements:
# We want to be able to add branching options to our code. How do we do this?

# %%
# Write an example of an if statement here:

# %% [markdown]
# ### 2. Additional conditions:
# What if we could add a second option to our if statement? A third? A seventeenth?

# %%
# Write an example of an if statement with multiple options:

# %% [markdown]
# ### 3. Comparison Operators:
# They say comparison is the thief of joy... Well that's not the case in python. Lets compare some things!

# %%
# Equal to:
print()

# Not equal to:
print()

# Less than:
print()

# Greater than:
print()

# Less than or equal to:
print()

# Greater than or equal to:
print()

# %% [markdown]
# ### Practice Time!
# Try completing the following coding task(s) in the cell(s) below.
# 1) Check if you name is "greater than" your instructors name.
#    If it is, print `"I'm the best"`.
#
# 2) Check if the number `400` is the same as the string `'400'`.
#    If it is, print `"numbers aren't real"`.
#    Otherwise, print `'I love math!'`

# %%
# Challenge 1:

# %%
# Challenge 2:

# %% [markdown]
# ### 4. Logical Operators
# Logical operators take one or two boolean values (True/False) and return a singular boolean value.
# This allows us to check multiple conditions in one statement.

# %%
sky_is_blue = True
earth_is_flat = False

# NOT
print()

# AND
print()

# OR
print()

# %% [markdown]
# ### 5. The While Loop
# Sometimes we don't feel like writing the same code over and over again, what if we could just tell one step to repeat.

# %%
# Create some while loops:

# %% [markdown]
# ### Project Time: Higher or Lower
#
# In a new python file, create a program that allows users to play a simple guessing game.
# The program should do the following:
#
# 1. Secretly set the winning number between 1 and 100
#
# 2. Display a welcome message.
#
# 3. Ask the user to guess a number between 1 and 100.
#
# 4. Inform the user if the guess is too high or too low.
#
# 5. If the guess is incorrect, repeat from step 3.
#    If the guess is correct, display win message and exit the program.
#
# Bonus features: (Complete if you have extra time)
# 1. Give the player a limited number of guesses to guess the number.
#
# 2. Make the winning number randomly chosen so you can play the game yourself.
#    (Ask instructor for directions on how to do this)
